# %%
# %pip install --upgrade --quiet  google-search-results
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from typing import Dict, List, Optional,Literal
from typing import TypedDict
from langgraph.graph import StateGraph, END
from langchain_core.messages import AIMessage
from langchain_community.tools.google_jobs import GoogleJobsQueryRun
from langchain_community.utilities.google_jobs import GoogleJobsAPIWrapper
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
import json
import os
import dotenv
import re
from datetime import datetime, timedelta

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
os.environ["SERPAPI_API_KEY"] = os.getenv("SERPAPI_API_KEY")
tool = GoogleJobsQueryRun(api_wrapper=GoogleJobsAPIWrapper())

# %%
print(os.environ["SERPAPI_API_KEY"])
# Out:
# [your serpapi key]

# %%
tool.run("Data Science last one week job postings")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 tool.run("Data Science last one week job postings")
#
# File c:\Users\AlfejMansuriMAQSoftw\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\tools\base.py:725, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     723 if error_to_raise:
#     724     run_manager.on_tool_error(error_to_raise)
# --> 725     raise error_to_raise
#     726 output = _format_output(content, artifact, tool_call_id, self.name, status)
#     727 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\AlfejMansuriMAQSoftw\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\tools\base.py:694, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     692 if config_param := _get_runnable_config_param(self._run):
#     693     tool_kwargs = tool_kwargs | {config_param: config}
# --> 694 response = context.run(self._run, *tool_args, **tool_kwargs)
#     695 if self.response_format == "content_and_artifact":
#     696     if not isinstance(response, tuple) or len(response) != 2:
#
# File c:\Users\AlfejMansuriMAQSoftw\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_community\tools\google_jobs\tool.py:29, in GoogleJobsQueryRun._run(self, query, run_manager)
#      23 def _run(
#      24     self,
#      25     query: str,
#      26     run_manager: Optional[CallbackManagerForToolRun] = None,
#      27 ) -> str:
#      28     """Use the tool."""
# ---> 29     return self.api_wrapper.run(query)
#
# File c:\Users\AlfejMansuriMAQSoftw\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_community\utilities\google_jobs.py:67, in GoogleJobsAPIWrapper.run(self, query)
#      65 total_results = []
#      66 client = self.serp_search_engine(params)
# ---> 67 total_results = client.get_dict()["jobs_results"]
#      69 # extract 1 job info:
#      70 res_str = ""
#
# KeyError: 'jobs_results'
